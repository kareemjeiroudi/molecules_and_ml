# %% [markdown]
# ## First Notes
#
# Please do not run the file as whole, as some cells include some irrelevant code that was created for testing some examples. The cells to be ignored are noted by a **BEGIN:** and **END;** notations.

# %% [markdown]
# ### Modules Import
#
# First, let's go through the imports we'll need for this session. I’ll need RDkit for molecular conversion and fingerprints calculation, numpy for and data management and numpy arrays, Scikit-learn for standardisation and data set splitting as well as Keras for the neural network building and training.

# %%
from __future__ import print_function
from rdkit import Chem

# %% [markdown]
# ### Reading data
#
# Reading a set of molecules an `SDMolSupplier` from rdkit.<br>
# In the [getting started](https://www.rdkit.org/docs/GettingStartedInPython.html) documentation there're two these two different suppliers, but I haven't looked up the difference yet:
# * `rdkit.Chem.rdmolfiles.SDMolSupplier`
# * `rdkit.Chem.rdmolfiles.SmilesMolSupplier`

# %%
## Read the file
supplier = Chem.SDMolSupplier('data/cas_4337.sdf')

# %%
type(supplier)
# Out:
# rdkit.Chem.rdmolfiles.SDMolSupplier

# %%
mol = supplier[97]
mol
# list(mol.GetPropNames())
mol.GetProp("Ames test categorisation")
# Out:
# 'mutagen'

# %%
## for each molecule, get the number of atoms in it
for mol in supplier:
    print(mol.GetNumAtoms())
# Out:
# 25
# 13
# 20
# 10
# 10
# 14
# 18
# 24
# 10
# 24
# 18
# 26
# 18
# 13
# 9
# 17
# 13
# 23
# 6
# 10
# 11
# 13
# 14
# 12
# 21
# 9
# 13
# 13
# 16
# 28
# 21
# 30
# 10
# 10
# 17
# 19
# 14
# 17
# 15
# 11
# 17
# 39
# 18
# 16
# 22
# 17
# 10
# 14
# 5
# 21
# 22
# 4
# 29
# 14
# 20
# 8
# 15
# 18
# 13
# 23
# 9
# 12
# 15
# 9
# 12
# 13
# 8
# 22
# 26
# 13
# 8
# 14
# 19
# 6
# 14
# 14
# 20
# 9
# 12
# 17
# 9
# 21
# 18
# 11
# 18
# 9
# 24
# 51
# 16
# 19
# 13
# 18
# 3
# 21
# 19
# 21
# 12
# 40
# 27
# 18
# 16
# 15
# 8
# 27
# 7
# 26
# 13
# 20
# 12
# 7
# 10
# 9
# 21
# 21
# 13
# 11
# 9
# 22
# 4
# 8
# 5
# 21
# 9
# 20
# 15
# 13
# 37
# 7
# 25
# 14
# 15
# 22
# 16
# 6
# 22
# 10
# 17
# 21
# 21
# 7
# 8
# 15
# 6
# 14
# 25
# 21
# 16
# 10
# 17
# 13
# 22
# 16
# 19
# 29
# 15
# 25
# 22
# 5
# 37
# 33
# 10
# 17
# 102
# 21
# 21
# 18
# 18
# 20
# 11
# 21
# 14
# 11
# 9
# 9
# 23
# 21
# 25
# 8
# 14
# 5
# 14
# 25
# 5
# 12
# 18
# 39
# 18
# 10
# 24
# 13
# 11
# 19
# 13
# 22
# 23
# 19
# 19
# 17
# 20
# 5
# 20
# 19
# 14
# 19
# 8
# 9
# 11
# 18
# 16
# 21
# 8
# 36
# 23
# 14
# 16
# 4
# 12
# 6
# 15
# 20
# 11
# 10
# 20
# 25
# 15
# 6
# 17
# 20
# 18
# 13
# 18
# 16
# 8
# 22
# 13
# 10
# 7
# 25
# 23
# 9
# 16
# 14
# 13
# 9
# 5
# 5
# 18
# 12
# 17
# 20
# 18
# 10
# 12
# 21
# 34
# 3
# 9
# 18
# 7
# 35
# 25
# 15
# 10
# 9
# 16
# 22
# 38
# 7
# 11
# 9
# 19
# 24
# 5
# 12
# 8
# 8
# 20
# 22
# 6
# 11
# 13
# 23
# 12
# 23
# 18
# 20
# 11
# 14
# 20
# 6
# 20
# 40
# 11
# 43
# 16
# 52
# 18
# 13
# 23
# 11
# 13
# 12
# 11
# 18
# 7
# 8
# 10
# 19
# 11
# 8
# 11
# 26
# 9
# 11
# 11
# 16
# 21
# 18
# 15
# 13
# 22
# 18
# 13
# 13
# 19
# 9
# 14
# 14
# 19
# 15
# 5
# 10
# 14
# 10
# 10
# 10
# 16
# 12
# 15
# 16
# 13
# 19
# 9
# 19
# 17
# 15
# 10
# 20
# 16
# 21
# 8
# 12
# 14
# 14
# 22
# 18
# 17
# 12
# 5
# 20
# 21
# 21
# 13
# 4
# 7
# 6
# 30
# 5
# 21
# 20
# 13
# 19
# 22
# 15
# 19
# 20
# 8
# 7
# 21
# 8
# 9
# 23
# 8
# 19
# 10
# 16
# 22
# 19
# 18
# 18
# 16
# 17
# 20
# 21
# 21
# 15
# 12
# 14
# 23
# 24
# 21
# 16
# 16
# 3
# 15
# 20
# 7
# 15
# 15
# 22
# 5
# 25
# 30
# 10
# 17
# 14
# 21
# 10
# 12
# 11
# 11
# 27
# 12
# 4
# 16
# 12
# 12
# 16
# 18
# 17
# 9
# 18
# 5
# 5
# 16
# 12
# 23
# 12
# 16
# 20
# 6
# 13
# 12
# 19
# 21
# 24
# 5
# 8
# 6
# 5
# 15
# 14
# 10
# 16
# 16
# 10
# 30
# 14
# 9
# 15
# 15
# 11
# 16
# 13
# 16
# 15
# 24
# 21
# 16
# 13
# 25
# 10
# 21
# 9
# 17
# 23
# 13
# 11
# 7
# 17
# 22
# 23
# 15
# 11
# 16
# 23
# 13
# 10
# 19
# 10
# 20
# 10
# 19
# 9
# 16
# 7
# 26
# 20
# 18
# 17
# 15
# 9
# 9
# 8
# 11
# 10
# 43
# 10
# 12
# 22
# 9
# 10
# 12
# 5
# 10
# 21
# 12
# 8
# 17
# 53
# 8
# 6
# 14
# 23
# 16
# 20
# 39
# 10
# 22
# 14
# 19
# 5
# 17
# 18
# 21
# 10
# 6
# 10
# 12
# 5
# 14
# 19
# 24
# 22
# 9
# 20
# 13
# 17
# 18
# 5
# 8
# 23
# 38
# 20
# 19
# 9
# 14
# 14
# 13
# 42
# 17
# 10
# 17
# 10
# 21
# 21
# 12
# 23
# 56
# 14
# 6
# 7
# 26
# 10
# 22
# 9
# 13
# 8
# 23
# 12
# 22
# 13
# 13
# 4
# 11
# 5
# 23
# 6
# 15
# 16
# 8
# 22
# 15
# 17
# 18
# 19
# 20
# 10
# 11
# 27
# 22
# 17
# 19
# 12
# 12
# 24
# 22
# 12
# 10
# 3
# 11
# 13
# 4
# 16
# 19
# 9
# 20
# 22
# 23
# 11
# 34
# 9
# 10
# 13
# 9
# 24
# 19
# 19
# 14
# 14
# 19
# 9
# 22
# 28
# 14
# 22
# 12
# 13
# 20
# 16
# 6
# 17
# 42
# 13
# 21
# 21
# 7
# 23
# 26
# 15
# 11
# 7
# 15
# 8
# 16
# 22
# 25
# 18
# 8
# 6
# 17
# 38
# 24
# 30
# 25
# 32
# 13
# 7
# 25
# 22
# 16
# 10
# 18
# 9
# 23
# 32
# 5
# 10
# 16
# 17
# 5
# 22
# 15
# 39
# 23
# 23
# 16
# 20
# 14
# 22
# 21
# 18
# 21
# 22
# 9
# 18
# 23
# 28
# 11
# 18
# 22
# 12
# 19
# 17
# 6
# 24
# 15
# 20
# 32
# 26
# 41
# 21
# 18
# 27
# 10
# 28
# 9
# 24
# 12
# 14
# 12
# 21
# 19
# 20
# 11
# 19
# 18
# 15
# 22
# 8
# 13
# 44
# 19
# 25
# 17
# 22
# 18
# 10
# 8
# 12
# 26
# 24
# 10
# 15
# 16
# 27
# 24
# 24
# 35
# 12
# 6
# 20
# 10
# 20
# 12
# 24
# 29
# 14
# 22
# 23
# 6
# 17
# 8
# 12
# 22
# 10
# 5
# 11
# 25
# 18
# 16
# 23
# 19
# 18
# 18
# 20
# 17
# 14
# 27
# 10
# 19
# 9
# 15
# 12
# 12
# 9
# 28
# 5
# 17
# 17
# 8
# 20
# 11
# 22
# 14
# 20
# 7
# 16
# 24
# 44
# 11
# 18
# 6
# 14
# 18
# 22
# 19
# 9
# 19
# 15
# 17
# 6
# 10
# 17
# 13
# 12
# 18
# 18
# 12
# 7
# 9
# 6
# 29
# 23
# 12
# 13
# 25
# 9
# 52
# 22
# 18
# 5
# 5
# 13
# 8
# 28
# 19
# 27
# 13
# 15
# 10
# 21
# 14
# 29
# 13
# 19
# 197
# 13
# 36
# 62
# 9
# 16
# 17
# 10
# 21
# 19
# 23
# 21
# 14
# 15
# 18
# 16
# 21
# 9
# 15
# 10
# 15
# 8
# 12
# 19
# 17
# 11
# 9
# 9
# 25
# 23
# 20
# 37
# 16
# 22
# 19
# 22
# 10
# 17
# 16
# 20
# 11
# 11
# 23
# 14
# 9
# 13
# 19
# 11
# 10
# 14
# 15
# 27
# 55
# 13
# 20
# 15
# 12
# 25
# 20
# 24
# 17
# 12
# 24
# 10
# 16
# 19
# 19
# 15
# 23
# 6
# 19
# 17
# 13
# 9
# 13
# 19
# 14
# 18
# 15
# 8
# 28
# 16
# 6
# 21
# 23
# 15
# 8
# 14
# 55
# 7
# 23
# 17
# 25
# 16
# 10
# 17
# 9
# 11
# 18
# 5
# 24
# 9
# 10
# 7
# 35
# 12
# 15
# 40
# 19
# 10
# 4
# 21
# 21
# 9
# 18
# 15
# 11
# 19
# 11
# 7
# 10
# 6
# 20
# 5
# 6
# 24
# 10
# 12
# 9
# 10
# 21
# 19
# 30
# 14
# 31
# 5
# 13
# 15
# 19
# 12
# 11
# 12
# 13
# 21
# 23
# 7
# 14
# 31
# 21
# 17
# 15
# 29
# 18
# 13
# 5
# 8
# 8
# 32
# 12
# 13
# 21
# 14
# 21
# 11
# 11
# 24
# 15
# 21
# 11
# 21
# 22
# 15
# 15
# 23
# 22
# 11
# 14
# 8
# 13
# 6
# 10
# 9
# 15
# 25
# 15
# 17
# 17
# 11
# 18
# 8
# 9
# 16
# 6
# 12
# 39
# 23
# 12
# 21
# 21
# 4
# 13
# 10
# 21
# 17
# 26
# 16
# 9
# 15
# 7
# 5
# 19
# 24
# 9
# 13
# 22
# 20
# 16
# 17
# 14
# 22
# 18
# 27
# 10
# 19
# 12
# 28
# 22
# 12
# 10
# 11
# 19
# 9
# 11
# 23
# 19
# 17
# 17
# 8
# 10
# 16
# 11
# 30
# 17
# 43
# 52
# 10
# 12
# 11
# 20
# 9
# 20
# 14
# 9
# 10
# 11
# 11
# 13
# 11
# 16
# 5
# 22
# 10
# 38
# 14
# 19
# 20
# 25
# 17
# 20
# 11
# 23
# 34
# 28
# 11
# 13
# 10
# 12
# 21
# 20
# 22
# 16
# 9
# 18
# 16
# 22
# 5
# 22
# 12
# 15
# 11
# 8
# 34
# 22
# 18
# 6
# 58
# 9
# 26
# 13
# 10
# 11
# 21
# 19
# 9
# 13
# 9
# 14
# 11
# 17
# 7
# 8
# 9
# 22
# 19
# 11
# 16
# 8
# 5
# 11
# 20
# 28
# 12
# 30
# 6
# 11
# 26
# 17
# 3
# 11
# 16
# 12
# 23
# 12
# 12
# 17
# 12
# 31
# 15
# 11
# 12
# 90
# 8
# 11
# 14
# 9
# 27
# 20
# 24
# 23
# 12
# 3
# 13
# 11
# 3
# 9
# 32
# 15
# 13
# 13
# 20
# 11
# 22
# 20
# 20
# 15
# 11
# 22
# 27
# 19
# 16
# 17
# 9
# 18
# 17
# 11
# 8
# 19
# 18
# 16
# 21
# 13
# 19
# 7
# 8
# 17
# 14
# 23
# 27
# 22
# 26
# 10
# 5
# 8
# 22
# 14
# 22
# 13
# 6
# 26
# 16
# 18
# 9
# 10
# 22
# 24
# 46
# 29
# 19
# 18
# 17
# 9
# 11
# 33
# 10
# 21
# 9
# 20
# 9
# 18
# 11
# 22
# 21
# 6
# 22
# 14
# 8
# 5
# 9
# 25
# 27
# 18
# 12
# 23
# 16
# 20
# 9
# 18
# 20
# 9
# 10
# 14
# 22
# 8
# 13
# 12
# 10
# 17
# 12
# 13
# 8
# 22
# 4
# 12
# 16
# 19
# 18
# 20
# 4
# 11
# 23
# 6
# 19
# 12
# 21
# 21
# 10
# 20
# 10
# 21
# 11
# 12
# 17
# 57
# 23
# 37
# 16
# 10
# 16
# 12
# 16
# 19
# 19
# 22
# 13
# 13
# 17
# 11
# 24
# 18
# 14
# 11
# 17
# 6
# 10
# 12
# 10
# 20
# 10
# 17
# 16
# 13
# 17
# 15
# 11
# 21
# 20
# 16
# 19
# 7
# 25
# 20
# 10
# 16
# 21
# 12
# 22
# 6
# 20
# 23
# 10
# 16
# 20
# 12
# 12
# 12
# 8
# 11
# 9
# 12
# 20
# 16
# 16
# 32
# 22
# 23
# 26
# 10
# 15
# 11
# 10
# 3
# 26
# 19
# 13
# 14
# 8
# 20
# 21
# 13
# 18
# 8
# 19
# 20
# 9
# 26
# 14
# 32
# 35
# 17
# 17
# 18
# 25
# 10
# 12
# 21
# 6
# 16
# 7
# 20
# 17
# 15
# 11
# 22
# 16
# 18
# 33
# 5
# 17
# 15
# 6
# 14
# 24
# 18
# 20
# 31
# 16
# 20
# 13
# 9
# 9
# 26
# 41
# 23
# 12
# 11
# 19
# 19
# 17
# 3
# 4
# 19
# 17
# 13
# 7
# 5
# 12
# 11
# 10
# 29
# 10
# 20
# 24
# 11
# 18
# 18
# 20
# 9
# 10
# 15
# 12
# 22
# 24
# 16
# 28
# 7
# 22
# 14
# 5
# 31
# 23
# 6
# 10
# 17
# 15
# 17
# 11
# 8
# 9
# 15
# 14
# 16
# 10
# 10
# 15
# 9
# 10
# 16
# 14
# 7
# 20
# 21
# 13
# 9
# 15
# 9
# 13
# 11
# 8
# 10
# 16
# 16
# 19
# 19
# 12
# 10
# 17
# 23
# 18
# 7
# 11
# 6
# 16
# 8
# 11
# 16
# 16
# 11
# 20
# 20
# 11
# 30
# 19
# 9
# 7
# 8
# 18
# 16
# 17
# 20
# 17
# 9
# 10
# 9
# 9
# 18
# 12
# 20
# 34
# 11
# 19
# 17
# 20
# 10
# 7
# 26
# 10
# 25
# 13
# 25
# 18
# 21
# 10
# 28
# 23
# 27
# 15
# 39
# 12
# 19
# 14
# 6
# 11
# 14
# 17
# 7
# 11
# 13
# 14
# 47
# 20
# 24
# 11
# 11
# 17
# 18
# 10
# 23
# 60
# 7
# 23
# 7
# 9
# 13
# 20
# 25
# 14
# 20
# 15
# 12
# 19
# 23
# 7
# 12
# 13
# 16
# 22
# 24
# 15
# 15
# 12
# 11
# 8
# 12
# 28
# 7
# 11
# 20
# 19
# 4
# 13
# 24
# 16
# 17
# 4
# 9
# 23
# 19
# 12
# 14
# 9
# 19
# 6
# 21
# 23
# 11
# 16
# 23
# 102
# 7
# 17
# 11
# 13
# 16
# 12
# 12
# 22
# 15
# 9
# 11
# 18
# 15
# 14
# 17
# 19
# 8
# 20
# 32
# 21
# 9
# 14
# 19
# 15
# 8
# 14
# 27
# 11
# 13
# 11
# 21
# 9
# 9
# 20
# 8
# 21
# 27
# 20
# 13
# 16
# 20
# 19
# 14
# 21
# 16
# 26
# 10
# 15
# 14
# 12
# 18
# 8
# 7
# 19
# 13
# 20
# 20
# 5
# 10
# 11
# 8
# 27
# 8
# 14
# 23
# 9
# 21
# 194
# 9
# 8
# 19
# 6
# 17
# 13
# 9
# 11
# 21
# 16
# 16
# 31
# 9
# 9
# 21
# 17
# 19
# 16
# 7
# 9
# 18
# 7
# 10
# 25
# 30
# 19
# 22
# 11
# 30
# 19
# 8
# 14
# 20
# 3
# 7
# 7
# 32
# 7
# 22
# 8
# 11
# 25
# 14
# 5
# 20
# 6
# 20
# 23
# 26
# 14
# 14
# 33
# 18
# 27
# 17
# 11
# 19
# 10
# 10
# 16
# 20
# 8
# 16
# 20
# 24
# 22
# 33
# 10
# 18
# 18
# 19
# 18
# 11
# 25
# 28
# 21
# 14
# 22
# 29
# 15
# 17
# 11
# 17
# 7
# 19
# 4
# 8
# 16
# 12
# 12
# 13
# 16
# 17
# 18
# 10
# 10
# 17
# 12
# 18
# 14
# 21
# 9
# 11
# 11
# 6
# 19
# 14
# 14
# 41
# 11
# 11
# 15
# 16
# 15
# 22
# 18
# 5
# 10
# 15
# 20
# 4
# 21
# 6
# 18
# 7
# 15
# 17
# 21
# 18
# 20
# 22
# 15
# 9
# 22
# 16
# 8
# 16
# 9
# 23
# 7
# 8
# 11
# 15
# 7
# 16
# 6
# 22
# 7
# 26
# 18
# 19
# 22
# 31
# 6
# 13
# 18
# 27
# 6
# 146
# 14
# 26
# 15
# 18
# 10
# 10
# 17
# 16
# 15
# 8
# 18
# 18
# 14
# 58
# 18
# 19
# 3
# 20
# 11
# 15
# 13
# 9
# 14
# 12
# 11
# 15
# 13
# 21
# 23
# 9
# 23
# 20
# 22
# 13
# 16
# 6
# 20
# 21
# 20
# 19
# 19
# 20
# 13
# 24
# 21
# 5
# 20
# 19
# 15
# 17
# 27
# 19
# 15
# 23
# 6
# 17
# 20
# 23
# 16
# 9
# 19
# 19
# 26
# 11
# 20
# 39
# 9
# 15
# 16
# 21
# 28
# 9
# 21
# 8
# 20
# 6
# 13
# 12
# 24
# 11
# 23
# 4
# 12
# 26
# 22
# 17
# 16
# 25
# 19
# 12
# 15
# 18
# 9
# 11
# 25
# 23
# 24
# 12
# 19
# 9
# 23
# 24
# 24
# 18
# 12
# 4
# 12
# 11
# 23
# 9
# 7
# 24
# 7
# 28
# 15
# 11
# 14
# 10
# 12
# 22
# 20
# 9
# 12
# 23
# 16
# 5
# 22
# 21
# 21
# 5
# 23
# 15
# 26
# 10
# 17
# 7
# 11
# 15
# 16
# 20
# 13
# 26
# 14
# 18
# 16
# 8
# 31
# 7
# 14
# 18
# 23
# 10
# 13
# 15
# 16
# 19
# 12
# 71
# 12
# 23
# 12
# 4
# 42
# 19
# 6
# 8
# 14
# 18
# 29
# 15
# 17
# 14
# 8
# 26
# 8
# 21
# 21
# 9
# 10
# 13
# 4
# 16
# 14
# 24
# 33
# 21
# 19
# 34
# 22
# 12
# 13
# 11
# 11
# 19
# 13
# 18
# 34
# 12
# 22
# 12
# 26
# 6
# 20
# 22
# 10
# 25
# 13
# 9
# 14
# 14
# 61
# 17
# 20
# 8
# 12
# 7
# 18
# 19
# 9
# 14
# 9
# 22
# 16
# 15
# 8
# 16
# 20
# 11
# 4
# 14
# 5
# 16
# 6
# 13
# 16
# 23
# 4
# 12
# 12
# 10
# 24
# 38
# 12
# 8
# 23
# 22
# 46
# 6
# 8
# 22
# 15
# 8
# 19
# 8
# 11
# 23
# 16
# 18
# 18
# 17
# 18
# 9
# 13
# 11
# 10
# 23
# 11
# 11
# 6
# 16
# 11
# 6
# 9
# 5
# 22
# 13
# 15
# 17
# 9
# 14
# 7
# 11
# 19
# 21
# 11
# 17
# 12
# 16
# 6
# 64
# 10
# 7
# 16
# 7
# 22
# 20
# 9
# 15
# 13
# 14
# 13
# 19
# 16
# 27
# 16
# 13
# 5
# 6
# 40
# 13
# 18
# 38
# 12
# 15
# 24
# 22
# 14
# 11
# 29
# 20
# 5
# 10
# 13
# 22
# 28
# 22
# 13
# 24
# 14
# 18
# 23
# 23
# 8
# 14
# 7
# 28
# 20
# 17
# 11
# 26
# 9
# 9
# 21
# 20
# 21
# 24
# 17
# 13
# 8
# 11
# 20
# 14
# 7
# 14
# 8
# 14
# 10
# 5
# 18
# 17
# 19
# 20
# 5
# 15
# 14
# 15
# 18
# 26
# 20
# 4
# 9
# 6
# 6
# 17
# 29
# 13
# 15
# 19
# 11
# 17
# 31
# 14
# 9
# 13
# 21
# 19
# 12
# 21
# 12
# 17
# 16
# 7
# 12
# 16
# 15
# 25
# 18
# 9
# 19
# 6
# 16
# 17
# 16
# 15
# 12
# 23
# 24
# 19
# 20
# 9
# 12
# 40
# 18
# 5
# 23
# 9
# 18
# 14
# 18
# 10
# 11
# 12
# 20
# 32
# 14
# 7
# 16
# 19
# 21
# 12
# 10
# 29
# 23
# 17
# 26
# 19
# 24
# 23
# 5
# 15
# 10
# 19
# 20
# 12
# 11
# 10
# 17
# 17
# 15
# 8
# 22
# 12
# 17
# 10
# 11
# 14
# 11
# 13
# 16
# 8
# 21
# 21
# 28
# 8
# 26
# 16
# 29
# 19
# 17
# 17
# 23
# 13
# 16
# 16
# 11
# 12
# 5
# 13
# 15
# 8
# 10
# 16
# 13
# 18
# 21
# 17
# 7
# 15
# 24
# 9
# 23
# 13
# 12
# 18
# 9
# 21
# 18
# 22
# 16
# 11
# 22
# 16
# 9
# 3
# 43
# 13
# 24
# 22
# 17
# 16
# 11
# 16
# 24
# 9
# 16
# 26
# 24
# 10
# 4
# 9
# 6
# 12
# 23
# 4
# 14
# 16
# 14
# 15
# 20
# 15
# 15
# 16
# 14
# 21
# 23
# 18
# 4
# 17
# 6
# 11
# 30
# 14
# 17
# 21
# 24
# 23
# 11
# 33
# 7
# 10
# 23
# 16
# 8
# 9
# 10
# 15
# 22
# 17
# 6
# 21
# 31
# 16
# 13
# 13
# 20
# 11
# 24
# 18
# 27
# 19
# 10
# 32
# 10
# 6
# 9
# 20
# 23
# 12
# 12
# 16
# 22
# 26
# 11
# 19
# 20
# 9
# 20
# 28
# 11
# 21
# 12
# 7
# 12
# 15
# 13
# 23
# 20
# 12
# 24
# 17
# 12
# 9
# 19
# 10
# 24
# 17
# 12
# 14
# 15
# 18
# 11
# 8
# 16
# 12
# 11
# 5
# 20
# 4
# 15
# 14
# 10
# 22
# 31
# 16
# 19
# 11
# 11
# 11
# 43
# 27
# 23
# 17
# 18
# 18
# 31
# 19
# 22
# 19
# 15
# 18
# 5
# 6
# 29
# 24
# 16
# 20
# 31
# 9
# 19
# 8
# 13
# 19
# 18
# 16
# 9
# 16
# 13
# 21
# 7
# 14
# 13
# 14
# 25
# 17
# 6
# 20
# 16
# 15
# 20
# 19
# 12
# 9
# 9
# 19
# 25
# 16
# 28
# 9
# 15
# 29
# 16
# 21
# 8
# 13
# 11
# 20
# 5
# 17
# 23
# 14
# 24
# 22
# 24
# 24
# 8
# 11
# 11
# 14
# 6
# 29
# 13
# 28
# 18
# 5
# 19
# 23
# 17
# 29
# 7
# 22
# 18
# 16
# 41
# 14
# 25
# 5
# 26
# 26
# 23
# 14
# 23
# 21
# 11
# 19
# 17
# 19
# 15
# 11
# 4
# 28
# 26
# 10
# 18
# 18
# 8
# 71
# 21
# 29
# 14
# 10
# 29
# 12
# 19
# 12
# 13
# 10
# 9
# 13
# 13
# 32
# 21
# 9
# 23
# 29
# 20
# 16
# 6
# 16
# 10
# 7
# 21
# 16
# 12
# 26
# 19
# 25
# 20
# 7
# 11
# 4
# 16
# 17
# 7
# 12
# 14
# 20
# 21
# 13
# 5
# 20
# 13
# 10
# 20
# 23
# 28
# 16
# 15
# 21
# 8
# 8
# 15
# 23
# 14
# 12
# 8
# 9
# 20
# 19
# 13
# 3
# 16
# 19
# 19
# 17
# 14
# 17
# 11
# 42
# 22
# 13
# 30
# 12
# 10
# 24
# 17
# 15
# 23
# 20
# 16
# 30
# 9
# 18
# 14
# 12
# 16
# 4
# 23
# 26
# 7
# 6
# 23
# 15
# 19
# 52
# 18
# 18
# 18
# 6
# 28
# 20
# 39
# 17
# 27
# 8
# 5
# 28
# 15
# 15
# 24
# 14
# 14
# 19
# 36
# 15
# 25
# 21
# 17
# 11
# 13
# 30
# 7
# 22
# 10
# 20
# 18
# 5
# 14
# 26
# 17
# 20
# 15
# 23
# 21
# 6
# 6
# 21
# 17
# 14
# 12
# 23
# 10
# 17
# 22
# 20
# 8
# 14
# 10
# 8
# 22
# 9
# 13
# 19
# 12
# 15
# 29
# 6
# 13
# 20
# 17
# 11
# 20
# 24
# 7
# 6
# 14
# 21
# 14
# 11
# 18
# 16
# 10
# 8
# 18
# 23
# 20
# 6
# 13
# 12
# 18
# 19
# 18
# 9
# 6
# 31
# 7
# 21
# 23
# 19
# 20
# 12
# 28
# 25
# 19
# 22
# 8
# 19
# 11
# 14
# 9
# 16
# 21
# 11
# 7
# 7
# 20
# 9
# 17
# 22
# 16
# 13
# 24
# 12
# 6
# 8
# 18
# 12
# 16
# 7
# 36
# 4
# 18
# 10
# 13
# 21
# 22
# 4
# 16
# 22
# 19
# 13
# 25
# 6
# 16
# 9
# 14
# 24
# 12
# 17
# 23
# 27
# 20
# 7
# 30
# 18
# 15
# 11
# 24
# 14
# 5
# 20
# 12
# 26
# 14
# 14
# 12
# 14
# 17
# 5
# 28
# 23
# 15
# 7
# 12
# 14
# 4
# 19
# 11
# 14
# 6
# 34
# 18
# 19
# 14
# 11
# 24
# 11
# 14
# 29
# 7
# 5
# 7
# 20
# 42
# 25
# 11
# 18
# 16
# 27
# 11
# 13
# 24
# 4
# 11
# 7
# 19
# 23
# 11
# 18
# 14
# 17
# 10
# 23
# 7
# 14
# 14
# 11
# 31
# 12
# 8
# 12
# 15
# 13
# 31
# 19
# 18
# 6
# 17
# 21
# 19
# 20
# 12
# 19
# 5
# 21
# 13
# 20
# 9
# 6
# 28
# 17
# 8
# 22
# 12
# 16
# 8
# 4
# 18
# 12
# 10
# 56
# 19
# 22
# 17
# 19
# 30
# 8
# 18
# 7
# 8
# 12
# 20
# 28
# 62
# 14
# 8
# 13
# 15
# 18
# 10
# 16
# 20
# 11
# 20
# 50
# 9
# 20
# 24
# 14
# 19
# 14
# 11
# 18
# 8
# 4
# 18
# 9
# 25
# 18
# 11
# 37
# 5
# 12
# 17
# 9
# 12
# 14
# 14
# 17
# 13
# 14
# 17
# 18
# 39
# 5
# 12
# 15
# 14
# 6
# 26
# 10
# 8
# 10
# 18
# 13
# 10
# 11
# 11
# 22
# 16
# 32
# 20
# 7
# 15
# 11
# 24
# 6
# 21
# 11
# 10
# 18
# 14
# 19
# 12
# 10
# 13
# 8
# 21
# 10
# 13
# 18
# 17
# 20
# 16
# 8
# 9
# 6
# 21
# 11
# 11
# 14
# 10
# 19
# 6
# 13
# 9
# 12
# 10
# 20
# 23
# 11
# 12
# 15
# 10
# 12
# 19
# 10
# 35
# 22
# 10
# 22
# 14
# 14
# 19
# 27
# 12
# 10
# 9
# 11
# 13
# 9
# 12
# 11
# 12
# 7
# 18
# 22
# 9
# 18
# 19
# 14
# 18
# 8
# 23
# 15
# 6
# 6
# 8
# 17
# 50
# 20
# 11
# 5
# 18
# 7
# 23
# 7
# 22
# 16
# 21
# 17
# 68
# 16
# 17
# 13
# 18
# 17
# 16
# 20
# 7
# 24
# 18
# 14
# 36
# 6
# 8
# 12
# 2
# 12
# 8
# 10
# 15
# 15
# 9
# 5
# 7
# 18
# 16
# 9
# 7
# 12
# 17
# 10
# 19
# 16
# 12
# 24
# 13
# 22
# 15
# 12
# 19
# 7
# 15
# 9
# 14
# 22
# 21
# 11
# 11
# 17
# 25
# 18
# 10
# 15
# 5
# 8
# 17
# 11
# 11
# 6
# 15
# 18
# 5
# 11
# 9
# 36
# 7
# 20
# 23
# 14
# 12
# 11
# 24
# 23
# 11
# 13
# 17
# 18
# 17
# 19
# 19
# 14
# 18
# 12
# 16
# 9
# 15
# 11
# 7
# 17
# 20
# 6
# 12
# 16
# 23
# 17
# 16
# 9
# 14
# 12
# 12
# 8
# 11
# 21
# 15
# 15
# 19
# 15
# 20
# 11
# 12
# 20
# 33
# 28
# 6
# 19
# 19
# 9
# 13
# 6
# 13
# 9
# 108
# 13
# 2
# 4
# 24
# 17
# 17
# 8
# 17
# 24
# 16
# 19
# 17
# 13
# 12
# 19
# 10
# 20
# 22
# 12
# 14
# 7
# 18
# 14
# 24
# 32
# 27
# 7
# 11
# 17
# 10
# 15
# 20
# 49
# 26
# 4
# 30
# 17
# 19
# 12
# 9
# 17
# 12
# 19
# 9
# 10
# 16
# 41
# 20
# 19
# 19
# 15
# 18
# 21
# 5
# 24
# 8
# 13
# 21
# 21
# 11
# 9
# 19
# 11
# 18
# 11
# 30
# 20
# 12
# 6
# 26
# 37
# 15
# 16
# 22
# 4
# 18
# 5
# 26
# 17
# 28
# 17
# 14
# 22
# 8
# 30
# 18
# 10
# 17
# 24
# 15
# 26
# 20
# 15
# 16
# 18
# 11
# 12
# 13
# 15
# 18
# 17
# 14
# 8
# 61
# 28
# 17
# 14
# 11
# 19
# 16
# 6
# 21
# 11
# 10
# 9
# 7
# 20
# 13
# 22
# 19
# 6
# 17
# 19
# 13
# 15
# 19
# 23
# 7
# 12
# 15
# 20
# 12
# 24
# 9
# 29
# 15
# 22
# 6
# 11
# 12
# 10
# 25
# 18
# 18
# 12
# 24
# 19
# 7
# 17
# 30
# 16
# 16
# 17
# 21
# 21
# 14
# 23
# 13
# 9
# 14
# 18
# 24
# 18
# 11
# 14
# 7
# 28
# 14
# 12
# 23
# 8
# 14
# 13
# 6
# 16
# 8
# 11
# 24
# 14
# 17
# 13
# 20
# 20
# 20
# 12
# 19
# 27
# 22
# 19
# 20
# 23
# 19
# 24
# 14
# 5
# 21
# 4
# 7
# 12
# 6
# 13
# 16
# 11
# 19
# 20
# 21
# 17
# 10
# 17
# 9
# 16
# 25
# 19
# 10
# 7
# 12
# 12
# 17
# 14
# 11
# 22
# 19
# 24
# 13
# 12
# 46
# 26
# 19
# 12
# 31
# 15
# 18
# 18
# 7
# 17
# 28
# 9
# 17
# 17
# 32
# 11
# 16
# 14
# 16
# 32
# 15
# 13
# 11
# 26
# 14
# 19
# 21
# 28
# 7
# 11
# 5
# 15
# 18
# 16
# 13
# 36
# 8
# 16
# 21
# 10
# 12
# 19
# 9
# 22
# 19
# 8
# 33
# 7
# 11
# 12
# 21
# 13
# 21
# 10
# 11
# 8
# 14
# 10
# 20
# 10
# 19
# 17
# 12
# 20
# 28
# 11
# 19
# 10
# 16
# 6
# 24
# 7
# 14
# 25
# 13
# 17
# 22
# 14
# 6
# 22
# 17
# 12
# 5
# 10
# 5
# 3
# 10
# 11
# 13
# 11
# 10
# 15
# 20
# 31
# 4
# 21
# 14
# 4
# 27
# 18
# 10
# 19
# 11
# 8
# 25
# 11
# 4
# 11
# 5
# 13
# 7
# 15
# 23
# 18
# 18
# 10
# 24
# 22
# 16
# 19
# 25
# 25
# 12
# 47
# 10
# 18
# 20
# 18
# 9
# 14
# 18
# 12
# 11
# 13
# 27
# 11
# 8
# 23
# 17
# 9
# 15
# 18
# 9
# 22
# 17
# 14
# 9
# 5
# 13
# 18
# 11
# 9
# 8
# 27
# 13
# 18
# 15
# 12
# 5
# 20
# 4
# 15
# 24
# 14
# 22
# 11
# 23
# 4
# 22
# 6
# 12
# 18
# 12
# 10
# 20
# 5
# 5
# 26
# 8
# 17
# 7
# 2
# 10
# 16
# 15
# 19
# 22
# 17
# 7
# 20
# 16
# 13
# 15
# 15
# 12
# 15
# 22
# 20
# 22
# 6
# 60
# 20
# 15
# 11
# 17
# 12
# 9
# 6
# 16
# 23
# 26
# 12
# 9
# 11
# 11
# 20
# 29
# 7
# 22
# 16
# 22
# 27
# 19
# 12
# 14
# 16
# 6
# 11
# 19
# 40
# 23
# 13
# 11
# 12
# 16
# 9
# 14
# 3
# 14
# 21
# 9
# 41
# 22
# 6
# 10
# 10
# 18
# 22
# 22
# 14
# 14
# 15
# 17
# 38
# 14
# 41
# 18
# 6
# 13
# 13
# 21
# 8
# 14
# 21
# 14
# 15
# 9
# 19
# 14
# 20
# 17
# 10
# 5
# 22
# 10
# 13
# 16
# 6
# 11
# 10
# 19
# 17
# 28
# 5
# 19
# 20
# 11
# 19
# 7
# 22
# 29
# 7
# 7
# 17
# 17
# 17
# 10
# 17
# 17
# 19
# 5
# 19
# 19
# 13
# 14
# 51
# 10
# 21
# 6
# 20
# 11
# 10
# 9
# 23
# 16
# 9
# 16
# 11
# 51
# 23
# 12
# 9
# 9
# 7
# 26
# 12
# 21
# 22
# 12
# 26
# 18
# 14
# 19
# 17
# 10
# 9
# 6
# 7
# 19
# 21
# 10
# 9
# 10
# 20
# 23
# 28
# 18
# 18
# 14
# 18
# 17
# 12
# 31
# 23
# 12
# 11
# 22
# 10
# 18
# 16
# 22
# 12
# 12
# 11
# 11
# 7
# 10
# 21
# 6
# 21
# 22
# 11
# 25
# 17
# 14
# 18
# 11
# 10
# 7
# 16
# 17
# 18
# 20
# 5
# 22
# 19
# 5
# 17
# 11
# 18
# 6
# 10
# 13
# 31
# 6
# 6
# 22
# 19
# 21
# 6
# 18
# 13
# 20
# 28
# 10
# 13
# 23
# 13
# 20
# 4
# 16
# 15
# 9
# 8
# 13
# 22
# 22
# 23
# 8
# 25
# 11
# 18
# 16
# 9
# 16
# 7
# 20
# 19
# 20
# 13
# 16
# 5
# 12
# 22
# 23
# 11
# 5
# 5
# 10
# 12
# 18
# 21
# 16
# 14
# 12
# 22
# 37
# 6
# 22
# 22
# 18
# 21
# 10
# 23
# 214
# 28
# 14
# 10
# 7
# 36
# 22
# 58
# 13
# 10
# 26
# 13
# 22
# 8
# 21
# 19
# 23
# 17
# 14
# 22
# 11
# 19
# 11
# 15
# 15
# 10
# 20
# 29
# 23
# 8
# 9
# 10
# 20
# 7
# 6
# 25
# 7
# 11
# 20
# 41
# 23
# 6
# 12
# 31
# 22
# 7
# 21
# 20
# 17
# 12
# 16
# 15
# 4
# 36
# 23
# 28
# 12
# 21
# 19
# 18
# 11
# 8
# 21
# 10
# 11
# 12
# 54
# 20
# 12
# 12
# 16
# 12
# 14
# 16
# 11
# 3
# 39
# 30
# 28
# 24
# 9
# 13
# 10
# 18
# 9
# 30
# 34
# 15
# 23
# 27
# 52
# 19
# 11
# 34
# 52
# 42
# 20
# 48
# 60
# 44
# 35
# 17
# 38
# 58
# 24
# 28
# 29
# 29
# 14
# 30
# 54
# 24
# 7
# 22
# 46
# 20
# 31
# 8
# 3
# 20
# 21
# 23
# 23
# 20
# 18
# 28
# 8
# 8
# 58
# 33
# 17
# 19
# 9
# 12
# 12
# 19
# 11
# 9
# 17
# 29
# 24
# 13
# 11
# 29
# 28
# 65
# 12
# 19
# 10
# 8
# 11
# 12
# 25
# 18
# 32
# 37
# 26
# 25
# 22
# 7
# 46
# 17
# 21
# 9
# 19
# 18
# 23
# 17
# 25
# 19
# 22
# 42
# 48
# 15
# 21
# 24
# 8
# 11
# 29
# 13
# 38
# 8
# 11
# 23
# 27
# 45
# 12
# 24
# 26
# 21
# 20
# 10
# 44
# 90
# 17
# 9
# 25
# 30
# 21
# 22
# 30
# 46
# 18
# 43
# 13
# 21
# 12
# 17
# 11
# 15
# 9
# 10
# 22
# 23
# 19
# 19
# 16
# 17
# 10
# 17
# 32
# 14
# 10
# 10
# 15
# 13
# 9
# 24
# 28
# 12
# 22
# 22
# 20
# 10
# 11
# 83
# 28
# 18
# 25
# 10
# 10
# 29
# 29
# 16
# 15
# 12
# 9
# 16
# 18
# 6
# 11
# 8
# 4
# 9
# 25
# 8
# 18
# 26
# 28
# 5
# 14
# 5
# 8
# 13
# 11
# 6
# 10
# 14
# 23
# 4
# 16
# 18
# 19
# 10
# 13
# 22
# 30
# 13
# 12
# 14
# 26
# 21
# 18
# 22
# 39
# 8
# 11
# 64
# 5
# 13
# 30
# 19
# 18
# 20
# 15
# 31
# 21
# 30
# 26
# 34
# 52
# 15
# 20
# 20
# 34
# 65
# 38
# 19
# 14
# 29
# 44
# 10
# 26
# 18
# 9
# 40
# 39
# 19
# 28
# 18
# 40
# 11
# 15
# 31
# 20
# 28
# 46
# 21
# 16
# 16
# 10
# 13
# 14
# 12
# 37
# 12
# 62
# 15
# 25
# 23
# 20
# 13
# 25
# 9
# 44
# 87
# 32
# 17
# 7
# 18
# 96
# 30
# 29
# 30
# 29
# 16
# 38
# 18
# 25
# 24
# 12
# 11
# 35
# 32
# 22
# 27
# 23
# 16
# 22
# 10
# 59
# 11
# 11
# 28
# 13
# 18
# 23
# 26
# 18
# 20
# 27
# 22
# 13
# 17
# 29
# 9
# 3
# 19
# 5
# 19
# 28
# 16
# 31
# 13
# 6
# 17
# 17
# 23
# 16
# 10
# 11
# 29
# 22
# 57
# 34
# 33
# 29
# 58
# 8
# 26
# 22
# 43
# 42
# 19
# 14
# 18
# 60
# 20
# 8
# 8
# 7
# 26
# 17
# 10
# 34
# 19
# 12
# 11
# 7
# 31
# 34
# 17
# 7
# 18

# %% [markdown]
# We have 4337 molecules in the data set:

# %%
len(supplier)
# Out:
# 4337

# %% [markdown]
# A good practice is to test each molecule to see if it was correctly read before working with it:

# %%
for mol in supplier:
    if mol is None:
        print("a None molecule was found!")
        
## if the output is empty the data is fine.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ---
# *The following code can be ignored, cause this was generated for my own interest and testing.*
#
# ---
# BEGIN:

# %%
m = Chem.MolFromSmiles('C1OC1')
for atom in m.GetAtoms():
    print(atom.GetAtomicNum())

print(m.GetBonds()[1].GetBondType())
# Out:
# 6
# 8
# 6
# SINGLE

# %% [markdown]
# END;
#
# ----
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Calculating Morgan fingerprints
#
# We're going to go trough two steps:<br>
#
# First, we'll obtain the training samples, which are going to be the bits value returned by the function `AllChem.GetMorganFingerprintAsBitVect`.<br>This is typically the output of calculating the morgan fingerprints for each molecule. Please refer to the subsection '**Explaiing bit from Morgan Fingerprints**' to understand the output.<br>
# After that we'd only need to turn it to a numpy array, because according to Keras's documentation: "Training set is expected to be a numpy array (if the model has a single input), or list of Numpy arrays (if the model has multiple inputs)."
#
# Second, extracting the labels for each molecule where a Morgan fingerprint can be located.
#
# #### Training Samples

# %%
import numpy as np
from rdkit.Chem import AllChem

# %% [markdown]
# > **\_\_TASK\_\_:** for each molecule calculate MorganFingerprints (with radius <b>3</b>) and size **~2048** (rdkit has also a nice easy function for that)
#
# Numpy array of training data (if the model has a single input), or list of Numpy arrays (if the model has multiple inputs).

# %%
info = {} # this variable will be mutated in the next function (very similar to pointers in C)
# fingerprints = [list(AllChem.GetMorganFingerprint(mol, 3, bitInfo=info)) for mol in supplier]

## calculate the Morgan Fingerprints for every molecule in the supplier
fingerprints = [AllChem.GetMorganFingerprintAsBitVect(mol, 3, nBits=2048, bitInfo=info) for mol in supplier]
# fingerprints=[list(fp) for fp in fingerprints_asBitVector]
fingerprints = np.array(fingerprints)

# %%
fingerprints.shape
# Out:
# (4337, 2048)

# %% [markdown]
# ##### Atoms contributing to the activation of Morgan fingerprints
#
# > **\_\_TASK\_\_:** Important! when you calculate the Fingerprints, save which atoms where responsible for the activation of the fingerprint (rdkit can also do that)
#
# ###### `bitsInfo` - Explaining bits from Morgan Fingerprints
#
# Information is available about the atoms that contribute to particular bits in the Morgan fingerprint via the bitInfo argument. The dictionary provided is populated with one entry per bit set in the fingerprint, <u>the keys are the bit ids</u>, <u>the values are lists of (atom index, radius) tuples</u>.
#
# And there we go. Now have succefully extracted the training samples that are ready to be passed to the model.
#
# So let's have a look on the dictionary in `info`:

# %%
info
# Out:
# {97: ((14, 0),),
#  191: ((10, 1),),
#  263: ((4, 2),),
#  314: ((7, 1), (9, 1)),
#  325: ((15, 3),),
#  336: ((2, 2), (3, 2)),
#  389: ((17, 2),),
#  484: ((6, 3), (8, 3)),
#  606: ((11, 2),),
#  650: ((5, 0), (7, 0), (9, 0)),
#  689: ((1, 1),),
#  703: ((12, 2), (13, 2)),
#  807: ((1, 0),),
#  811: ((6, 2), (8, 2)),
#  856: ((11, 3),),
#  905: ((0, 3),),
#  993: ((0, 2),),
#  1019: ((0, 0),),
#  1034: ((2, 1), (3, 1)),
#  1060: ((6, 1), (8, 1)),
#  1077: ((10, 2),),
#  1088: ((15, 1), (16, 1), (17, 1)),
#  1114: ((6, 0), (8, 0)),
#  1152: ((4, 0),),
#  1199: ((15, 2), (16, 2)),
#  1216: ((1, 3),),
#  1327: ((10, 3),),
#  1380: ((2, 0), (3, 0), (10, 0), (11, 0)),
#  1460: ((12, 3),),
#  1642: ((4, 3),),
#  1645: ((11, 1),),
#  1682: ((1, 2),),
#  1717: ((14, 1),),
#  1750: ((12, 1), (13, 1)),
#  1771: ((0, 1),),
#  1816: ((4, 1),),
#  1873: ((12, 0), (13, 0), (15, 0), (16, 0), (17, 0)),
#  1917: ((5, 1),),
#  1947: ((17, 3),),
#  2037: ((2, 3),)}

# %% [markdown]
# <br>
#
# Interpreting the results above:
#
# ```
# 97: ((14, 0),),
# 191: ((10, 1),),
# 314: ((7, 1), (9, 1)),
# ```
#
# * bit 97 is set once: by atom 14 with radius 0.
# * bit 191 is set also once: by atom 10, with radius 1.
# * bit 314, on the other hand, is set twice: once by atom 7 and once with atom 9, each with radius 1.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ---
# *The following code can be ignored, cause this was generated for my own interest and testing.*
#
# ---
# BEGIN:
#
# In the following I'd like to draw one molecule in order to locate the Morgan fingerprint, together with the atoms and radius. So let's draw the molecule first, then let's find out what the following values correspond to:<br>
# The first entry in the `info` dictionary is `97: ((14, 0),),`, so we'll see what that means.<br>
# Lastly, I'll repeat the same process but with molecule number 314 whose fingerprints are `314: ((7, 1), (9, 1)),`

# %%
from rdkit.Chem import Draw

# %% [markdown]
# END;
#
# ----
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# #### Training Labels
#
# Now that we've got the the bits ready as training samples (i.e. features) for the model, we still need to extract the label to have a target for our predictions.
#
# The property that we want to extract out of the list of prooperties, is whether or not the 'Ames test Categorisation' is a mutagen.
# * 1 for mutagen
# * 0 for nonmutagen

# %%
training_labels = []
for mol in supplier:
    if mol.GetProp("Ames test categorisation") == "mutagen":
        training_labels.append(1)
    else:
        training_labels.append(0)

training_labels = np.array(training_labels)

# %%
len(training_labels)
# Out:
# 4337

# %% [markdown]
# Now, we've got the whole training set ready. Let's move on to extracting the validation set.
#
# #### Validation Set
#
# In order to select a 'valid' validation, we have randomly picked the following indices of molecules.<br>
# Additionally, we'd still need to see how many fingerprints are expressed in this set of molecules.
#
# In the following, I'll be using the alias `val_`, for anything that's related to the validation set, in order to avoid length variables names.

# %%
## KAREEM: these molecules I got from Kristina!
val_mol_ids = [6,   10,   29,   32,   42,   58,   72,   83,   98,  100,  128, 
        145,  148,  168,  171,  205,  208,  237,  244,  285,  290,  291,
         300,  312,  332,  334,  335,  347,  356,  369,  371,  377,  407,
         424,  456,  458,  470,  472,  486,  514,  515,  528,  557,  563,
         599,  610,  616,  628,  640,  701,  704,  722,  764,  794,  818,
         821,  840,  850,  856,  859,  874,  878,  882,  898,  901,  925,
         936,  945,  957,  974,  977, 1013, 1019, 1030, 1038, 1047, 1049,
        1072, 1073, 1100, 1159, 1168, 1187, 1190, 1194, 1201, 1202, 1233,
        1247, 1258, 1264, 1273, 1283, 1288, 1300, 1302, 1319, 1339, 1349,
        1402, 1413, 1416, 1422, 1426, 1435, 1454, 1465, 1483, 1502, 1513,
        1515, 1520, 1548, 1576, 1604, 1606, 1621, 1650, 1695, 1696, 1711,
        1714, 1716, 1725, 1743, 1746, 1752, 1780, 1788, 1794, 1799, 1813,
        1826, 1866, 1886, 1901, 1903, 1921, 1929, 1940, 1969, 1970, 1997,
        1998, 2008, 2010, 2011, 2018, 2023, 2046, 2060, 2064, 2080, 2081,
        2131, 2171, 2182, 2203, 2212, 2224, 2231, 2241, 2246, 2283, 2294,
        2295, 2297, 2327, 2329, 2331, 2349, 2357, 2360, 2365, 2397, 2413,
        2417, 2418, 2421, 2448, 2467, 2510, 2516, 2528, 2533, 2549, 2562,
        2601, 2604, 2606, 2609, 2611, 2632, 2644, 2653, 2677, 2682, 2685,
        2692, 2703, 2708, 2714, 2719, 2726, 2732, 2759, 2761, 2776, 2780,
        2817, 2818, 2829, 2837, 2857, 2858, 2884, 2899, 2902, 2905, 2911,
        2939, 2975, 2977, 2986, 3007, 3009, 3018, 3024, 3038, 3066, 3087,
        3098, 3107, 3117, 3122, 3139, 3157, 3161, 3164, 3217, 3223, 3233,
        3263, 3265, 3271, 3290, 3295, 3307, 3313, 3317, 3321, 3382, 3384,
        3388, 3400, 3409, 3412, 3419, 3423, 3449, 3470, 3487, 3488, 3503,
        3509, 3511, 3539, 3562, 3626, 3637, 3654, 3662, 3663, 3668, 3671,
        3688, 3689, 3695, 3710, 3726, 3743, 3744, 3782, 3791, 3794, 3808,
        3809, 3841, 3849, 3874, 3910, 3912, 3925, 3945, 3950, 3958, 3959,
        3962, 3964, 3967, 3978, 3993, 4009, 4010, 4055, 4057, 4085, 4089,
        4096, 4099, 4107, 4112, 4129, 4135, 4151, 4155, 4196, 4209, 4216,
        4234, 4236, 4251, 4267, 4283, 4317, 4326, 4335

]
val_molecules = [supplier[i] for i in val_mol_ids]

# %%
len(val_molecules)
# Out:
# 327

# %%
val_info = {}
val_fingerprints = [AllChem.GetMorganFingerprintAsBitVect(mol, 3, nBits=2048, bitInfo=val_info) for mol in val_molecules]

# %%
val_labels = []
for mol in val_molecules:
    if mol.GetProp("Ames test categorisation") == "mutagen":
        val_labels.append(1)
    else:
        val_labels.append(0)

# %%
len(val_labels)
# Out:
# 327

# %% [markdown]
# The following is an insignificant change of the data. The atempt here is create a tuples of both validation fingerprints and label put together.

# %%
# val_set = [tuple(fingerprints[i], val_labels[i]) for i range(len(fingerprints))]
val_set = []
for i in range(len(val_fingerprints)):
    val_set.append((val_fingerprints[i], val_labels[i]))
    
val_set = np.array(val_set)
val_set.shape
# Out:
# (327, 2)

# %%
## here I'll try to recreate the vlidation set, I think it's a lot easier than I thought
val_set = (val_mol_ids, val_labels)
len(val_set)
# val_set = [(val_mol_ids[i], val_labels[i]) for i in range(len(val_labels))]
# val_set
# Out:
# 2

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# ## Creating The model

# %%
# to suppress the FutureWarning: conversion of the second argument of issubdtype 
# from 'float' to 'np.floatin' is deprecated
import os

# importing all libraries that we'd need
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.metrics import categorical_crossentropy

from sklearn import cross_validation
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score # Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores

# %% [markdown]
# From before we know that our data shape is `(4337, 2048)`
#
# Standard scaling is applied now, because the model cannot learn on som arbitrary numbers.

# %%
#Scale fingerprints to unit variance and zero mean
st = StandardScaler()
scaled_fingerprints= st.fit_transform(fingerprints)
# Out:
# /anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# Additionally, I'd like to scale down the validation fingerprints too.

# %%
scaled_val_fingerprints = st.fit_transform(val_fingerprints)

# %% [markdown]
# The first layer must get an input dimensions matching the data $=2048$, whereas the following can deduce their input size from the previous layer. For instance, the output size of the firs layer in my model is 5, beginning with the second layer, I don't need to specify the input size, because the layer can deduce that alone.

# %%
model = Sequential()
model.add(Dense(output_dim=5, input_dim=scaled_fingerprints.shape[1]))
## Kristina wouldn't use sigmoid, either relu or selu 
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
model.add(Activation("linear"))
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=2048, units=5)`
#
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
#   """

# %% [markdown]
# And I used the fasted learning rate possible because running 500 epochs takes relatively long time $(\approx1.5\,min)$ on my 2017 machine. For optimizers, I used standard stochastic gradient descent (**SGD**), which <...>.

# %%
model.compile(loss='mean_squared_error', optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), metrics=["accuracy"])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5)                 10245
# _________________________________________________________________
# activation_1 (Activation)    (None, 5)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 10,251
# Trainable params: 10,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# In order for us to predict the <>, we used the function `sklearn.metrics.roc_auc_score`, which computes Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.
# Note: this implementation is restricted to the binary classification task or multilabel classification task in label indicator format.

# %%
# history = model.fit(scaled_fingerprints, training_labels, validation_data=val_set.all(), epochs=500, batch_size=32, verbose=2)
## the best sofar
# history = model.fit(scaled_fingerprints, training_labels, validation_split=0.2, epochs=100, shuffle=True, batch_size=32, verbose=2)
# history = model.fit(scaled_fingerprints, training_labels, validation_data=(val_fingerprints, val_labels), epochs=500, batch_size=32, verbose=1)
#           callbacks=[TestCallback((X_test, Y_test))])
# Out:
# Train on 3469 samples, validate on 868 samples
# Epoch 1/100
#  - 1s - loss: 0.2146 - acc: 0.7068 - val_loss: 0.1750 - val_acc: 0.7454
# Epoch 2/100
#  - 0s - loss: 0.1040 - acc: 0.8746 - val_loss: 0.1702 - val_acc: 0.7742
# Epoch 3/100
#  - 0s - loss: 0.0831 - acc: 0.9080 - val_loss: 0.1744 - val_acc: 0.7811
# Epoch 4/100
#  - 0s - loss: 0.0708 - acc: 0.9291 - val_loss: 0.1771 - val_acc: 0.7753
# Epoch 5/100
#  - 0s - loss: 0.0618 - acc: 0.9429 - val_loss: 0.1891 - val_acc: 0.7604
# Epoch 6/100
#  - 0s - loss: 0.0550 - acc: 0.9504 - val_loss: 0.1892 - val_acc: 0.7592
# Epoch 7/100
#  - 0s - loss: 0.0496 - acc: 0.9602 - val_loss: 0.1997 - val_acc: 0.7592
# Epoch 8/100
#  - 0s - loss: 0.0448 - acc: 0.9683 - val_loss: 0.2026 - val_acc: 0.7569
# Epoch 9/100
#  - 0s - loss: 0.0411 - acc: 0.9706 - val_loss: 0.2088 - val_acc: 0.7615
# Epoch 10/100
#  - 0s - loss: 0.0376 - acc: 0.9729 - val_loss: 0.2145 - val_acc: 0.7523
# Epoch 11/100
#  - 0s - loss: 0.0343 - acc: 0.9767 - val_loss: 0.2201 - val_acc: 0.7523
# Epoch 12/100
#  - 0s - loss: 0.0312 - acc: 0.9813 - val_loss: 0.2260 - val_acc: 0.7431
# Epoch 13/100
#  - 0s - loss: 0.0289 - acc: 0.9847 - val_loss: 0.2303 - val_acc: 0.7385
# Epoch 14/100
#  - 0s - loss: 0.0264 - acc: 0.9876 - val_loss: 0.2337 - val_acc: 0.7339
# Epoch 15/100
#  - 0s - loss: 0.0244 - acc: 0.9890 - val_loss: 0.2381 - val_acc: 0.7350
# Epoch 16/100
#  - 0s - loss: 0.0227 - acc: 0.9916 - val_loss: 0.2446 - val_acc: 0.7304
# Epoch 17/100
#  - 0s - loss: 0.0208 - acc: 0.9916 - val_loss: 0.2489 - val_acc: 0.7166
# Epoch 18/100
#  - 0s - loss: 0.0190 - acc: 0.9934 - val_loss: 0.2540 - val_acc: 0.7166
# Epoch 19/100
#  - 0s - loss: 0.0176 - acc: 0.9939 - val_loss: 0.2575 - val_acc: 0.7085
# Epoch 20/100
#  - 0s - loss: 0.0161 - acc: 0.9951 - val_loss: 0.2616 - val_acc: 0.7051
# Epoch 21/100
#  - 0s - loss: 0.0153 - acc: 0.9954 - val_loss: 0.2626 - val_acc: 0.7120
# Epoch 22/100
#  - 0s - loss: 0.0140 - acc: 0.9960 - val_loss: 0.2704 - val_acc: 0.6982
# Epoch 23/100
#  - 0s - loss: 0.0131 - acc: 0.9971 - val_loss: 0.2729 - val_acc: 0.7039
# Epoch 24/100
#  - 0s - loss: 0.0120 - acc: 0.9960 - val_loss: 0.2756 - val_acc: 0.6947
# Epoch 25/100
#  - 0s - loss: 0.0113 - acc: 0.9968 - val_loss: 0.2786 - val_acc: 0.6982
# Epoch 26/100
#  - 0s - loss: 0.0105 - acc: 0.9971 - val_loss: 0.2838 - val_acc: 0.6935
# Epoch 27/100
#  - 0s - loss: 0.0096 - acc: 0.9983 - val_loss: 0.2848 - val_acc: 0.6924
# Epoch 28/100
#  - 0s - loss: 0.0089 - acc: 0.9974 - val_loss: 0.2880 - val_acc: 0.6935
# Epoch 29/100
#  - 0s - loss: 0.0082 - acc: 0.9983 - val_loss: 0.2926 - val_acc: 0.6855
# Epoch 30/100
#  - 0s - loss: 0.0076 - acc: 0.9983 - val_loss: 0.2966 - val_acc: 0.6901
# Epoch 31/100
#  - 0s - loss: 0.0072 - acc: 0.9983 - val_loss: 0.2986 - val_acc: 0.6843
# Epoch 32/100
#  - 0s - loss: 0.0068 - acc: 0.9983 - val_loss: 0.3023 - val_acc: 0.6797
# Epoch 33/100
#  - 0s - loss: 0.0065 - acc: 0.9983 - val_loss: 0.3035 - val_acc: 0.6751
# Epoch 34/100
#  - 0s - loss: 0.0060 - acc: 0.9986 - val_loss: 0.3057 - val_acc: 0.6774
# Epoch 35/100
#  - 0s - loss: 0.0057 - acc: 0.9988 - val_loss: 0.3094 - val_acc: 0.6682
# Epoch 36/100
#  - 0s - loss: 0.0054 - acc: 0.9991 - val_loss: 0.3100 - val_acc: 0.6740
# Epoch 37/100
#  - 0s - loss: 0.0052 - acc: 0.9988 - val_loss: 0.3128 - val_acc: 0.6705
# Epoch 38/100
#  - 0s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.3139 - val_acc: 0.6682
# Epoch 39/100
#  - 0s - loss: 0.0046 - acc: 0.9994 - val_loss: 0.3149 - val_acc: 0.6728
# Epoch 40/100
#  - 0s - loss: 0.0044 - acc: 0.9991 - val_loss: 0.3188 - val_acc: 0.6647
# Epoch 41/100
#  - 0s - loss: 0.0041 - acc: 0.9994 - val_loss: 0.3186 - val_acc: 0.6659
# Epoch 42/100
#  - 0s - loss: 0.0041 - acc: 0.9994 - val_loss: 0.3206 - val_acc: 0.6613
# Epoch 43/100
#  - 0s - loss: 0.0038 - acc: 0.9994 - val_loss: 0.3229 - val_acc: 0.6578
# Epoch 44/100
#  - 0s - loss: 0.0036 - acc: 0.9994 - val_loss: 0.3247 - val_acc: 0.6590
# Epoch 45/100
#  - 0s - loss: 0.0036 - acc: 0.9994 - val_loss: 0.3253 - val_acc: 0.6636
# Epoch 46/100
#  - 0s - loss: 0.0037 - acc: 0.9991 - val_loss: 0.3285 - val_acc: 0.6613
# Epoch 47/100
#  - 0s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.3286 - val_acc: 0.6567
# Epoch 48/100
#  - 0s - loss: 0.0031 - acc: 0.9994 - val_loss: 0.3298 - val_acc: 0.6601
# Epoch 49/100
#  - 0s - loss: 0.0029 - acc: 0.9994 - val_loss: 0.3310 - val_acc: 0.6578
# Epoch 50/100
#  - 0s - loss: 0.0027 - acc: 0.9994 - val_loss: 0.3317 - val_acc: 0.6682
# Epoch 51/100
#  - 0s - loss: 0.0027 - acc: 0.9994 - val_loss: 0.3337 - val_acc: 0.6601
# Epoch 52/100
#  - 0s - loss: 0.0025 - acc: 0.9994 - val_loss: 0.3341 - val_acc: 0.6590
# Epoch 53/100
#  - 0s - loss: 0.0025 - acc: 0.9994 - val_loss: 0.3367 - val_acc: 0.6567
# Epoch 54/100
#  - 0s - loss: 0.0024 - acc: 0.9994 - val_loss: 0.3376 - val_acc: 0.6647
# Epoch 55/100
#  - 0s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.3378 - val_acc: 0.6590
# Epoch 56/100
#  - 0s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.3390 - val_acc: 0.6601
# Epoch 57/100
#  - 0s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.3398 - val_acc: 0.6578
# Epoch 58/100
#  - 0s - loss: 0.0022 - acc: 0.9997 - val_loss: 0.3419 - val_acc: 0.6601
# Epoch 59/100
#  - 0s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.3418 - val_acc: 0.6578
# Epoch 60/100
#  - 0s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.3429 - val_acc: 0.6578
# Epoch 61/100
#  - 0s - loss: 0.0020 - acc: 0.9997 - val_loss: 0.3438 - val_acc: 0.6613
# Epoch 62/100
#  - 0s - loss: 0.0020 - acc: 0.9997 - val_loss: 0.3449 - val_acc: 0.6590
# Epoch 63/100
#  - 0s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.3445 - val_acc: 0.6624
# Epoch 64/100
#  - 0s - loss: 0.0018 - acc: 0.9997 - val_loss: 0.3475 - val_acc: 0.6590
# Epoch 65/100
#  - 0s - loss: 0.0017 - acc: 0.9997 - val_loss: 0.3472 - val_acc: 0.6578
# Epoch 66/100
#  - 0s - loss: 0.0017 - acc: 0.9997 - val_loss: 0.3491 - val_acc: 0.6567
# Epoch 67/100
#  - 0s - loss: 0.0016 - acc: 0.9997 - val_loss: 0.3491 - val_acc: 0.6567
# Epoch 68/100
#  - 0s - loss: 0.0016 - acc: 0.9997 - val_loss: 0.3511 - val_acc: 0.6567
# Epoch 69/100
#  - 0s - loss: 0.0015 - acc: 0.9997 - val_loss: 0.3498 - val_acc: 0.6555
# Epoch 70/100
#  - 0s - loss: 0.0015 - acc: 0.9997 - val_loss: 0.3529 - val_acc: 0.6567
# Epoch 71/100
#  - 0s - loss: 0.0015 - acc: 0.9997 - val_loss: 0.3516 - val_acc: 0.6567
# Epoch 72/100
#  - 0s - loss: 0.0015 - acc: 0.9997 - val_loss: 0.3529 - val_acc: 0.6544
# Epoch 73/100
#  - 0s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.3523 - val_acc: 0.6555
# Epoch 74/100
#  - 0s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.3550 - val_acc: 0.6544
# Epoch 75/100
#  - 0s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.3543 - val_acc: 0.6613
# Epoch 76/100
#  - 0s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.3557 - val_acc: 0.6555
# Epoch 77/100
#  - 0s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.3560 - val_acc: 0.6578
# Epoch 78/100
#  - 0s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.3562 - val_acc: 0.6567
# Epoch 79/100
#  - 0s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.3584 - val_acc: 0.6544
# Epoch 80/100
#  - 0s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.3577 - val_acc: 0.6544
# Epoch 81/100
#  - 0s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.3593 - val_acc: 0.6544
# Epoch 82/100
#  - 0s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.3591 - val_acc: 0.6521
# Epoch 83/100
#  - 0s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.3613 - val_acc: 0.6544
# Epoch 84/100
#  - 0s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.3604 - val_acc: 0.6521
# Epoch 85/100
#  - 0s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.3615 - val_acc: 0.6498
# Epoch 86/100
#  - 0s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.3624 - val_acc: 0.6521
# Epoch 87/100
#  - 0s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.3616 - val_acc: 0.6521
# Epoch 88/100
#  - 0s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.3629 - val_acc: 0.6509
# Epoch 89/100
#  - 0s - loss: 0.0010 - acc: 0.9997 - val_loss: 0.3629 - val_acc: 0.6544
# Epoch 90/100
#  - 0s - loss: 9.7257e-04 - acc: 0.9997 - val_loss: 0.3645 - val_acc: 0.6452
# Epoch 91/100
#  - 0s - loss: 9.5256e-04 - acc: 0.9997 - val_loss: 0.3635 - val_acc: 0.6532
# Epoch 92/100
#  - 0s - loss: 9.2295e-04 - acc: 0.9997 - val_loss: 0.3652 - val_acc: 0.6521
# Epoch 93/100
#  - 0s - loss: 8.9877e-04 - acc: 0.9997 - val_loss: 0.3640 - val_acc: 0.6532
# Epoch 94/100
#  - 0s - loss: 8.8248e-04 - acc: 0.9997 - val_loss: 0.3662 - val_acc: 0.6498
# Epoch 95/100
#  - 0s - loss: 8.7908e-04 - acc: 0.9997 - val_loss: 0.3659 - val_acc: 0.6463
# Epoch 96/100
#  - 0s - loss: 8.9116e-04 - acc: 0.9997 - val_loss: 0.3681 - val_acc: 0.6463
# Epoch 97/100
#  - 0s - loss: 9.0887e-04 - acc: 0.9997 - val_loss: 0.3673 - val_acc: 0.6452
# Epoch 98/100
#  - 0s - loss: 8.9581e-04 - acc: 0.9997 - val_loss: 0.3677 - val_acc: 0.6475
# Epoch 99/100
#  - 0s - loss: 8.8855e-04 - acc: 0.9997 - val_loss: 0.3675 - val_acc: 0.6498
# Epoch 100/100
#  - 0s - loss: 8.4132e-04 - acc: 0.9997 - val_loss: 0.3688 - val_acc: 0.6440

# %% [markdown]
# The recommendation of Kristina:<br>
# Use one `fit` and one `predict` at a time and instead of running multiple epochs, you can use a for loop in order for you validate the model.

# %%
for epoch in range(100):
    model.fit(scaled_fingerprints, training_labels, batch_size=32, epochs=1)
    predictions = model.predict(scaled_val_fingerprints)
    auc = roc_auc_score(val_labels, predictions, average="samples")
# Out:
# Epoch 1/1
# 4337/4337 [==============================] - 1s 137us/step - loss: 0.0171 - acc: 0.9767
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0180 - acc: 0.9763
# Epoch 1/1
# 4337/4337 [==============================] - 0s 85us/step - loss: 0.0179 - acc: 0.9767
# Epoch 1/1
# 4337/4337 [==============================] - 0s 85us/step - loss: 0.0178 - acc: 0.9760
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0173 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0171 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0169 - acc: 0.9767
# Epoch 1/1
# 4337/4337 [==============================] - 0s 85us/step - loss: 0.0169 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0170 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0167 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0166 - acc: 0.9769
# Epoch 1/1
# 4337/4337 [==============================] - 0s 85us/step - loss: 0.0166 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0165 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0166 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0165 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0163 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0166 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0165 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0163 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0163 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0165 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 85us/step - loss: 0.0173 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0166 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0164 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 86us/step - loss: 0.0165 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0163 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0161 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0163 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 89us/step - loss: 0.0164 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0164 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 109us/step - loss: 0.0163 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 99us/step - loss: 0.0163 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0164 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0166 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 98us/step - loss: 0.0168 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0167 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 97us/step - loss: 0.0164 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 89us/step - loss: 0.0163 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0163 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0163 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0168 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0169 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0173 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0169 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0171 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0172 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0186 - acc: 0.9765
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0249 - acc: 0.9730
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0199 - acc: 0.9756
# Epoch 1/1
# 4337/4337 [==============================] - 0s 102us/step - loss: 0.0197 - acc: 0.9763
# Epoch 1/1
# 4337/4337 [==============================] - 0s 96us/step - loss: 0.0184 - acc: 0.9767
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0170 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0166 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 90us/step - loss: 0.0165 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 87us/step - loss: 0.0163 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 99us/step - loss: 0.0160 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 87us/step - loss: 0.0164 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 96us/step - loss: 0.0189 - acc: 0.9772
# Epoch 1/1
# 4337/4337 [==============================] - 0s 87us/step - loss: 0.0168 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 87us/step - loss: 0.0160 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0163 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 102us/step - loss: 0.0156 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 108us/step - loss: 0.0154 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 101us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 110us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 95us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 104us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 104us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0151 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 102us/step - loss: 0.0152 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0160 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0161 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0160 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0159 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0166 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0170 - acc: 0.9774
# Epoch 1/1
# 4337/4337 [==============================] - 0s 107us/step - loss: 0.0160 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 89us/step - loss: 0.0155 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0157 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 88us/step - loss: 0.0158 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0159 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 89us/step - loss: 0.0160 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 89us/step - loss: 0.0157 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 87us/step - loss: 0.0159 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0169 - acc: 0.9779
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0164 - acc: 0.9776
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0158 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0156 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 94us/step - loss: 0.0153 - acc: 0.9781
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0151 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0150 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 98us/step - loss: 0.0150 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 93us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 90us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 91us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 90us/step - loss: 0.0149 - acc: 0.9783
# Epoch 1/1
# 4337/4337 [==============================] - 0s 92us/step - loss: 0.0148 - acc: 0.9783

# %%
auc
## OUTPUT: 0.9958941951108756
# Out:
# 0.9958941951108756

# %% [markdown]
# In the previous model we use ....,.... and got a $0.99589$ auc score, which is relatively a good score. However, we'd still need to see what parameters play the biggest role in order for this model to learn. i.e. what parameters have biggest influence on updating the weights of this model. By doing so, we are also able to understand more about the data.
#
# This model was heavily inspired by the example of [Esben Jannik Bjerrumm, PhD](https://www.linkedin.com/pulse/molecular-neural-network-models-rdkit-keras-python-bjerrum) on [prediction of molecular properties using Python, RDkit and Keras](http://www.wildcardconsulting.dk/useful-information/molecular-neural-network-models-with-rdkit-and-keras-in-python/). However, in the example Esben gave, he ...., eventually his Neural Network RMS score was $0.855494851649$. So we can realize that ... .
#
# Let's now together examine the success of this model's predictions.
# After fitting we can now easily predict the values of the test set and make a quick scatter plot to get a feeling of how well our model is doing in terms of prediction. auc seems relatively good, compared with other models built in this project.

# %%
import matplotlib.pyplot as plt

plt.scatter(training_labels, model.predict(scaled_fingerprints), label = 'Training data', c='red', alpha=0.8)
plt.title('Neural Network Predictor')
plt.xlabel('Measured bits')
plt.ylabel('Predicted bits')
plt.scatter(val_labels, model.predict(scaled_val_fingerprints), c='grey', label='validation data', alpha = 0.5)
plt.legend(loc=4)
plt.show();

# %% [markdown]
# #### Remark on the scatter plot:
#
# The plot here doesn't give any info about the prediction, because the type of classificaiton is *binary*. i.e. the output is either $0$ or $1$ ('nonmutagen' or 'mutagen'), unlike in *multilabel classification* where the output can any float value ranging from $0$ to $1$. Therefore, we should be using confusion matrix instead that shows true postives with respect to false postives, and true negatives with respect to false negatives - more on that in the following [**remark on Confusion Matrix**](Reading_sdf_file.ipynb#Remark-on-Confusion-Matrix).

# %%
# %matplotlib inline
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(val_labels, model.predict_classes(scaled_val_fingerprints))

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
cm_plot_labels = ['nonmutagen', 'mutagen']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[139   7]
#  [  3 178]]

# %%
count =0
for label in val_labels:
    if label == 1:
        count+=1
count
# Out:
# 181

# %% [markdown]
# #### Remark on Confusion Matrix:
#
# Just inorder to confirm the resutls of the confusion matrix, I used the cell above, which shows that indeed 181 labels were truely mutagen.
#
# Interpreting the results above:
# * In $3$ out of $181$ cases where the true label was '**mutagen**', the model predicted that it was '**nonmutagen**'.
# * In $7$ out of $146$ cases where the true label was '**nonmutage**', the model predited it to be '**mutagen**'.
# * The rest of predictions were accurate.
#
# Apparantly, the model has a lower chance of predicting nonmutagens than mutagens, indicated by the darker blue color on the plot above. Tweaking the parameters helps us findig which input from bits has highest significance during prediction.

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## Second Model
#
# Let's take a look on what things that are featurign this model. This model has ... learning rate instead of .... and instead .. and unline in the previous one it has ... instead .... . So how does this model comapre to the previous one in terms of accuracy, prediction, and auc score.

# %% [markdown]
# The following is a table that shows the comparison of all models. Learning rate, model architecture and and wether or not Dropout was used, are all depicted for each model:
#
# |Model_nr|Learning Rate|Dropout|Nom of layers |Activation Functions|       OutputLayer        |
# |--------|-------------|-------|--------------|--------------------|--------------------------|
# |1       |0.01         |no     |1 hidden layer|relu                |one-dimensional output dense with linear activation|
# |2       |
#
# Additionally, you can refer to the model's summary by typing `model.summary()` to see the architecture of the model together with the number of trainable parameters.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Conclusion
#
# Larger networks will overfit, unless some form of regularization is put in place (such as early stopping or drop out). As the output values are continuous rather than class labels, the output dimension is a single neuron with a linear activation.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
#
# ---
# <div style="text-align: center;"> <b>Please ingore everything below this here<b>
#
#     |
#     |
#     |
#     |
#     |
#     ٧
# </div>
#
# ---

# %%
model = Sequential([
    Dense(16, input_shape=(4337, 2048,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='sigmoid')
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 4337, 16)          32784
# _________________________________________________________________
# dense_44 (Dense)             (None, 4337, 32)          544
# _________________________________________________________________
# dense_45 (Dense)             (None, 4337, 2)           66
# =================================================================
# Total params: 33,394
# Trainable params: 33,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(fingerprints, training_labels, validation_data=val_set.all(), batch_size=20, epochs=20, shuffle=True, verbose=3)
# Out:
# Epoch 1/20
#  - 1s - loss: 0.2355
# Epoch 2/20
#  - 1s - loss: 0.2149
# Epoch 3/20
#  - 1s - loss: 0.1989
# Epoch 4/20
#  - 1s - loss: 0.1866
# Epoch 5/20
#  - 1s - loss: 0.1763
# Epoch 6/20
#  - 1s - loss: 0.1674
# Epoch 7/20
#  - 1s - loss: 0.1594
# Epoch 8/20
#  - 1s - loss: 0.1524
# Epoch 9/20
#  - 1s - loss: 0.1460
# Epoch 10/20
#  - 1s - loss: 0.1406
# Epoch 11/20
#  - 1s - loss: 0.1357
# Epoch 12/20
#  - 1s - loss: 0.1312
# Epoch 13/20
#  - 1s - loss: 0.1271
# Epoch 14/20
#  - 1s - loss: 0.1234
# Epoch 15/20
#  - 1s - loss: 0.1199
# Epoch 16/20
#  - 1s - loss: 0.1166
# Epoch 17/20
#  - 1s - loss: 0.1137
# Epoch 18/20
#  - 1s - loss: 0.1106
# Epoch 19/20
#  - 1s - loss: 0.1081
# Epoch 20/20
#  - 1s - loss: 0.1055
